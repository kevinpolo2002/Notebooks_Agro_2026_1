# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinpolo2002/Notebooks_Agro_2026_1/blob/main/Rendimiento_Extracci%C3%B3n_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Kevin Jose Polo Morales**

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el peso total de los racimos de fruta fresca (RFF) procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (tipo float) (Pr).
# 3. Solicitar los litros de aceite obtenidos (tipo float) (Lt).
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L (R)
# .
# $$  Pa=Lt×0.92 $$
# $$ R=(Pa/Pr)*100 $$
#
# **Prueba del programa:**
#
# Si se ingresan **1000 kg** de racimos y se obtienen **200 litros** de aceite, el programa debe informar que el rendimiento del lote es del **18.4%**.

# %%
# ENTRADA Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (tipo float) (Pr).
# Solicitar los litros de aceite obtenidos (tipo float) (Lt).
nombre = input("Ingrese el nombre del lote: ")
Pr = float(input("Ingrese el peso de los racimos en kg: "))
Lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

# PROCESO calcular el peso del aceite (Pa) y el rendimiento (R)
Pa = Lt * 0.92
R = (Pa / Pr) * 100

# SALIDA finformar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", R, "%")
# Out:
# Ingrese el nombre del lote: Perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote Perico es del 18.4 %

# %% [markdown]
# ```markdown
# Aquí está la explicación de cada línea de código del problema "Control de Rendimiento en Extracción de Aceite":
#
# ```python
# # ENTRADA Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (tipo float) (Pr).
# # Solicitar los litros de aceite obtenidos (tipo float) (Lt).
# nombre = input("Ingrese el nombre del lote: ")
# Pr = float(input("Ingrese el peso de los racimos en kg: "))
# Lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))
#
# # PROCESO calcular el peso del aceite (Pa) y el rendimiento (R)
# Pa = Lt * 0.92
# R = (Pa / Pr) * 100
#
# # SALIDA finformar el rendimiento del lote
# print("El rendimiento del lote", nombre, "es del", R, "%")
# ```
#
# **Explicación Línea por Línea:**
#
# 1.  `# ENTRADA Solicitar el nombre del lote de producción (Tipo string).`: Este es un comentario que indica la sección de entrada de datos y describe el primer dato que se solicitará al usuario.
# 2.  `# Solicitar el peso de los racimos en kg (tipo float) (Pr).`: Otro comentario que describe el segundo dato a solicitar, el peso de los racimos.
# 3.  `# Solicitar los litros de aceite obtenidos (tipo float) (Lt).`: Comentario que describe el tercer dato a solicitar, la cantidad de litros de aceite.
# 4.  `nombre = input("Ingrese el nombre del lote: ")`: Esta línea solicita al usuario que ingrese el nombre del lote de producción. La función `input()` lee la entrada del usuario como una cadena de texto (string), y este valor se almacena en la variable `nombre`.
# 5.  `Pr = float(input("Ingrese el peso de los racimos en kg: "))`: Aquí se solicita el peso de los racimos en kilogramos. La función `input()` obtiene la entrada del usuario. Luego, `float()` convierte esa entrada (que inicialmente es una cadena de texto) a un número de punto flotante (decimal), que es adecuado para valores de peso. El resultado se guarda en la variable `Pr`.
# 6.  `Lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))`: Similar a la línea anterior, esta solicita la cantidad de aceite crudo obtenido en litros. La entrada del usuario se convierte a un número de punto flotante usando `float()` y se almacena en la variable `Lt`.
# 7.  `# PROCESO calcular el peso del aceite (Pa) y el rendimiento (R)`: Un comentario que marca el inicio de la sección de procesamiento de los datos.
# 8.  `Pa = Lt * 0.92`: Esta línea calcula el peso del aceite (Pa). Multiplica la cantidad de litros de aceite (`Lt`) por su densidad (0.92 kg/L). El resultado se almacena en la variable `Pa`.
# 9.  `R = (Pa / Pr) * 100`: Esta línea calcula el Índice de Rendimiento de Extracción (IRE), o simplemente el rendimiento (`R`). Divide el peso del aceite (`Pa`) por el peso de los racimos (`Pr`) y luego multiplica el resultado por 100 para expresarlo como un porcentaje. El valor se guarda en la variable `R`.
# 10. `# SALIDA finformar el rendimiento del lote`: Comentario que indica el inicio de la sección de salida, donde se muestran los resultados.
# 11. `print("El rendimiento del lote", nombre, "es del", R, "%")`: Esta línea imprime el resultado final al usuario. Utiliza la función `print()` para mostrar una cadena de texto que incluye el nombre del lote (`nombre`), el valor del rendimiento calculado (`R`), y el símbolo de porcentaje, concatenando todas estas partes en un mensaje legible.
