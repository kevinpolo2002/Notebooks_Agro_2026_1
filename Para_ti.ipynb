# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinpolo2002/Notebooks_Agro_2026_1/blob/main/Para_ti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = '''
<style>
  @keyframes float {
    0% { transform: translateY(0px); }
    50% { transform: translateY(-10px); }
    100% { transform: translateY(0px); }
  }

  .flower-container {
    text-align: center;
    padding: 20px;
    background-color: #fffaf0; /* Color crema suave de fondo */
    border-radius: 15px;
    box-shadow: 0 4px 8px rgba(0,0,0,0.1);
    margin: 20px auto;
    max-width: 400px;
  }

  .yellow-flower {
    width: 100px; /* Tamaño de la imagen */
    height: auto;
    animation: float 3s ease-in-out infinite; /* Animación de flotar */
    margin-bottom: 15px;
  }

  .dedication-text {
    font-family: 'Georgia', serif;
    font-size: 1.1em;
    color: #333;
    line-height: 1.6;
  }

  .dedication-text em {
    color: #ff69b4; /* Rosa para resaltar */
    font-style: normal;
    font-weight: bold;
  }

</style>

<div class="flower-container">
  <img src="https://upload.wikimedia.org/wikipedia/commons/4/41/Yellow_flower_and_green_background.jpg"
       alt="Flores Amarillas Flotando" class="yellow-flower">
  <div class="dedication-text">
    Mi cielo,
    <p>En este día especial de Amor y Amistad, quiero recordarte lo mucho que significas para mí. Eres mi compañera, mi confidente, mi mejor amiga y el amor de mi vida. Cada momento a tu lado es un regalo, lleno de risas, apoyo y una conexión inquebrantable.</p>
    <p>Estas flores amarillas son un símbolo de la alegría, la luz y la profunda amistad que ilumina nuestra relación. Que su color vibrante represente la felicidad que me brindas y la promesa de muchos más momentos dorados juntos.</p>
    <p>Recuerdo con cariño aquel día en que nuestros caminos se cruzaron, y desde entonces, mi vida se ha llenado de una magia que solo tú podrías traer. Gracias por cada sonrisa, cada abrazo, cada palabra de aliento. Gracias por ser tú.</p>
    <p>Que este día esté lleno de amor, y que nuestro vínculo siga floreciendo con la misma intensidad que estas hermosas flores. Siempre tuyo/a, hoy y siempre.</p>
    <p>Con todo mi amor,<br><em>[Tu flako]</em></p>
  </div>
</div>
'''

display(HTML(html_content))
# Out:
# <style>
#   @keyframes float {
#     0% { transform: translateY(0px); }
#     50% { transform: translateY(-10px); }
#     100% { transform: translateY(0px); }
#   }
#
#   .flower-container {
#     text-align: center;
#     padding: 20px;
#     background-color: #fffaf0; /* Color crema suave de fondo */
#     border-radius: 15px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
#     margin: 20px auto;
#     max-width: 400px;
#   }
#
#   .yellow-flower {
#     width: 100px; /* Tamaño de la imagen */
#     height: auto;
#     animation: float 3s ease-in-out infinite; /* Animación de flotar */
#     margin-bottom: 15px;
#   }
#
#   .dedication-text {
#     font-family: 'Georgia', serif;
#     font-size: 1.1em;
#     color: #333;
#     line-height: 1.6;
#   }
#
#   .dedication-text em {
#     color: #ff69b4; /* Rosa para resaltar */
#     font-style: normal;
#     font-weight: bold;
#   }
#
# </style>
#
# <div class="flower-container">
# ...

# %% [markdown]
# Puedes copiar este código HTML y guardarlo como un archivo con extensión `.html` (por ejemplo, `tarjeta_amor.html`). Luego, puedes abrir ese archivo en un navegador para ver cómo queda.
#
# **Nota Importante para WhatsApp:**
#
# Para animaciones directas en WhatsApp, lo más práctico es usar un **GIF animado**. Puedes buscar GIFs de flores amarillas que te gusten o crear uno a partir de un video corto. WhatsApp permite enviar GIFs directamente en los chats.
